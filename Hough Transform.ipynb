# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in the image
image= cv2.imread('images/phone.jpg')

# Make a copy of the image
image_copy = np.copy(image)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %% [markdown]
# ## Perform edge detection

# %%
# Convert image to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

# define our parameters for Canny
low_threshold = 50
high_threshold= 100
edges = cv2.Canny(gray, low_threshold, high_threshold)

plt.imshow(edges, cmap='gray')

# %% [markdown]
# ## Find lines using a hough transform

# %%
# Define the Hough transform parameters
rho = 1 # 1 pixel
theta = np.pi/180 # 1 degree
threshold = 60 # minimum threshold to detect line
min_line_length = 100 # minimum line length
max_line_gap = 5 # gap between segmentation

# Find lines using a hoguh transform
lines = cv2.HoughLinesP(edges, rho, theta, threshold, np.array([]), min_line_length, max_line_gap)
## return 2D array

line_image = np.copy(image_copy)
for line in lines:
    for x1,y1,x2,y2 in line:
        cv2.line(line_image,(x1, y1), (x2, y2), (255,0,0),5)
        
plt.imshow(line_image)
